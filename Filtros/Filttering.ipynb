# %% [markdown]
# # Bibliotecas

# %%
import numpy as np
from scipy.io import wavfile
from scipy.signal import find_peaks, firwin, filtfilt, freqz, periodogram
import matplotlib.pyplot as plt

from FFT import *
from OverlapAdd import *

# %%
fs, x = wavfile.read('Dados/sinal_1.wav')

# %%
X = myFFT(x)
X = myFFTShift(X)

# %%
plt.figure(figsize=(16, 8))
plt.stem(np.arange(-fs//2, fs//2, fs/len(X)),np.abs(X))
# Out:
# <StemContainer object of 3 artists>

# %%
numtaps = 81
cutoff = 100
lf = 1500
hf = 2500

b = firwin(numtaps, [lf, hf], fs=fs, window='hamming', pass_zero=True)

# %%
plt.stem(np.abs(myFFTShift(myFFT(b))))
# Out:
# <StemContainer object of 3 artists>

# %%
y = myOverlapAdd(x, b, 512)

# %%
Y = myFFTShift(np.abs(myFFT(y)))

# %%
plt.figure(figsize=(16, 8))
plt.stem(np.arange(-fs//2, fs//2, fs/len(Y)),np.abs(Y))
# Out:
# <StemContainer object of 3 artists>
