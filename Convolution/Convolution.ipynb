# %% [markdown]
# ## Bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

from FFT import *

# %% [markdown]
# ## Convolução Circular

# %%
x1_n = np.ones(8)
x2_n = np.ones(4)

X1_k = myFFT(x1_n)
X2_k = myFFT(x2_n)

X_conv_k = X1_k * X2_k

x_conv_n = myIFFT(X_conv_k)

plt.stem(x_conv_n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 7
#       4 X1_k = myFFT(x1_n)
#       5 X2_k = myFFT(x2_n)
# ----> 7 X_conv_k = X1_k * X2_k
#       9 x_conv_n = myIFFT(X_conv_k)
#      11 plt.stem(x_conv_n)
#
# ValueError: operands could not be broadcast together with shapes (8,) (4,)

# %%
# Out:
# <StemContainer object of 3 artists>
